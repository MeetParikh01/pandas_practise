# %%
import numpy as np
import pandas as pd

# %%
num_state = np.random.RandomState(100)

# %%
ps = pd.Series(num_state.normal(10,4,20))
ps
# Out:
# 0     12.322293
# 1      5.581908
# 2     12.760486
# 3     12.747560
# 4      3.733250
# 5     13.619896
# 6     13.115290
# 7     11.712931
# 8     10.435488
# 9     10.113135
# 10     7.684697
# 11     5.202195
# 12     3.176192
# 13    11.476656
# 14    17.506294
# 15     8.492387
# 16    17.327744
# 17    10.012070
# 18     9.695906
# 19    10.015830
# dtype: float64

# %%
result = np.percentile(ps, q=[0, 25, 50, 75, 100])
result
# Out:
# array([ 3.17619198,  8.29046412, 10.27431125, 12.75079167, 17.50629371])

# %%
num_state.get_state()
# Out:
# ('MT19937', array([3360406328, 3390039568, 1158383459, 2464533760, 1940215510,
#         2199868565, 3384176493, 1479147319,  967981013, 2882491609,
#          391633118,  444027184, 1039381593, 3963376666, 1443078304,
#         2568878308,  930337588,  340726946,  553068851, 3021842216,
#         3153919216, 1740124441, 2510208264, 2456187274, 4134103905,
#         3301465484, 3483727560,  393466488,  974459003, 1805402025,
#         4220538419, 3552645889, 2112875403, 2512163862,   71864722,
#         1291130785, 1604294971,  538890468, 2262249227, 3285295176,
#         1986963503,  580977625, 2601681210, 3313699315, 2052084975,
#         2753303244, 4204292302, 1436797156, 3772641545,  687371615,
#          763107097, 2303030203, 2130269351, 1633192838, 1092171384,
#         1745403421, 2653384671,  236580281, 1229378369, 1786283546,
#         4246477669, 4250915914, 4132324948, 3589584962, 1913173597,
#         3642697290, 1828893463, 1962733397,  773320207,  565425494,
# ...
